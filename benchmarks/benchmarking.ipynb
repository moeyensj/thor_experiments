# %%
import os
import numpy as np
import pandas as pd
from astropy import units as u
from astropy.time import Time

import matplotlib.pyplot as plt

os.environ["OORB_DATA"] = "/home/moeyensj/software/oorb/share/oorb"

# %%
import pandas as pd
from astropy import units as u
from astropy.coordinates import SkyCoord


observations = pd.read_parquet("observations_201309.parquet")

coords = SkyCoord(ra=observations["ra"].values*u.deg, dec=observations["dec"].values*u.deg, frame="icrs")
observations["lon_galactic"] = coords.galactic.l.value
observations["lat_galactic"] = coords.galactic.b.value
observations["lon_ecliptic"] = coords.barycentrictrueecliptic.lon.value
observations["lat_ecliptic"] = coords.barycentrictrueecliptic.lat.value

# Only keep observations within some range of visits
visit_min = 6
visit_max = 20
visits = observations.groupby(by=["healpixel"])["mjd_utc"].nunique()
visits = visits[(visits >= visit_min) & (visits <= visit_max)]
observations_filtered = observations[observations['healpixel'].isin(visits.index.values)]

# Remove all observations near the galactic plane
observations_filtered = observations_filtered[(observations_filtered["lat_galactic"] >= 15) | (observations_filtered["lat_galactic"] <= -15)]

# Remove all observations far away from the ecliptic plane
observations_filtered = observations_filtered[(observations_filtered["lat_ecliptic"] <= 60) & (observations_filtered["lat_ecliptic"] >= -60)]

# %%
observations_filtered
# Out:
#           frame_id obscode                 exposure_id filter  \
# 28101      1390632     W84  c4d_130901_003155_ooi_g_d2      g
# 28103      1390632     W84  c4d_130901_003155_ooi_g_d2      g
# 28104      1390632     W84  c4d_130901_003155_ooi_g_d2      g
# 28105      1390632     W84  c4d_130901_003155_ooi_g_d2      g
# 28106      1390632     W84  c4d_130901_003155_ooi_g_d2      g
# ...            ...     ...                         ...    ...
# 13665858   1405306     W84  c4d_130930_061026_ooi_i_d2      i
# 13665859   1405306     W84  c4d_130930_061026_ooi_i_d2      i
# 13665860   1405306     W84  c4d_130930_061026_ooi_i_d2      i
# 13665861   1405306     W84  c4d_130930_061026_ooi_i_d2      i
# 13665862   1405306     W84  c4d_130930_061026_ooi_i_d2      i
#
#           exposure_mjd_start  exposure_mjd_mid  exposure_duration  healpixel  \
# 28101           56536.022172      56536.022693               90.0      11465
# 28103           56536.022172      56536.022693               90.0      11465
# 28104           56536.022172      56536.022693               90.0      11465
# 28105           56536.022172      56536.022693               90.0      11465
# 28106           56536.022172      56536.022693               90.0      11465
# ...                      ...               ...                ...        ...
# 13665858        56565.257250      56565.257771               90.0       8867
# 13665859        56565.257250      56565.257771               90.0       8867
# 13665860        56565.257250      56565.257771               90.0       8867
# 13665861        56565.257250      56565.257771               90.0       8867
# 13665862        56565.257250      56565.257771               90.0       8867
#
#                       obs_id       mjd_utc          ra        dec  ra_sigma  \
# 28101      c4d.229268.44.797  56536.022693  313.149715 -59.345394  0.000035
# 28103     c4d.229268.44.1135  56536.022693  312.991443 -59.327597  0.000026
# 28104     c4d.229268.44.1095  56536.022693  313.008272 -59.316254  0.000031
# 28105     c4d.229268.44.1075  56536.022693  313.013500 -59.311340  0.000053
# 28106     c4d.229268.44.1047  56536.022693  313.025591 -59.313235  0.000044
# ...                      ...           ...         ...        ...       ...
# 13665858  c4d.239722.18.1873  56565.257771    5.558317 -42.599820  0.000029
# 13665859  c4d.239722.18.1871  56565.257771    5.566702 -42.647946  0.000083
# 13665860  c4d.239722.18.1870  56565.257771    5.566803 -42.648505  0.000047
# 13665861  c4d.239722.18.1869  56565.257771    5.565718 -42.648523  0.000050
# 13665862   c4d.239722.23.338  56565.257771    5.368490 -42.693862  0.000029
#
#           dec_sigma        mag  mag_sigma  lon_galactic  lat_galactic  \
# 28101      0.000034  23.671648   0.178042    337.109806    -38.399147
# 28103      0.000026  23.473284   0.154616    337.152111    -38.323439
# 28104      0.000030  23.704840   0.160683    337.164180    -38.334057
# 28105      0.000052  23.257390   0.174081    337.169670    -38.337625
# 28106      0.000044  23.271868   0.184343    337.165776    -38.343312
# ...             ...        ...        ...           ...           ...
# 13665858   0.000029  19.938854   0.029307    322.075686    -73.425806
# 13665859   0.000083  20.562832   0.110122    321.989156    -73.384052
# 13665860   0.000047  21.142061   0.100398    321.988146    -73.383568
# 13665861   0.000050  20.068970   0.053143    321.990683    -73.383236
# 13665862   0.000029  22.768730   0.176733    322.391144    -73.283770
#
#           lon_ecliptic  lat_ecliptic
# 28101       297.026083    -39.889215
# 28103       296.935931    -39.844002
# 28104       296.951612    -39.836425
# 28105       296.957124    -39.832771
# 28106       296.963768    -39.836725
# ...                ...           ...
# 13665858    344.448805    -40.494884
# 13665859    344.422765    -40.539182
# 13665860    344.422464    -40.539698
# 13665861    344.421556    -40.539298
# 13665862    344.227648    -40.502464
#
# [3658835 rows x 20 columns]

# %%
from thor.orbits import Orbits
from astropy.time import Time

orbits = Orbits.fromHorizons(["2013 RR165"], Time([observations["mjd_utc"].min()], format="mjd", scale="utc"))
# Out:
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]

# %%
from thor import preprocessObservations

preprocessed_observations, preprocessed_associations = preprocessObservations(
    observations,
    {   
        "mjd" : "mjd_utc",
        "RA_deg" : "ra",
        "Dec_deg" : "dec",
        "RA_sigma_deg" : "ra_sigma",
        "Dec_sigma_deg" : "dec_sigma",
        "observatory_code" : "obscode",
        "obs_id" : "obs_id",
        "obj_id" : None,
    },
    mjd_scale="utc",
)
# Out:
# /home/moeyensj/projects/thor/thor_stable/thor/data_processing.py:152: UserWarning: No object ID column defined in the column_mapping dictionary.
# Assuming no observations have been associated with a known object...
#
#   warnings.warn(warning, UserWarning)
# /home/moeyensj/projects/thor/thor_stable/thor/data_processing.py:267: UserWarning: Observation IDs should be of type string, converting...
#   warnings.warn(warn)

# %%
0.005 * 3600
# Out:
# 18.0

# %%
from thor import runTHOR
from thor.config import Configuration

cell_areas = [1, 2.5, 5, 7.5, 10, 20]
algorithms = ["dbscan", "hotspot_2d"]
#algorithms = ["hotspot_2d"]
clustering_radius = [1, 5, 10, 15]

for algorithm in algorithms:
    for radius in clustering_radius:
        for cell_area in cell_areas:
            config = Configuration(
                min_obs=6,
                min_arc_length=1.0,
                range_shift_config={"cell_area": cell_area},
                cluster_link_config={"eps" : radius/3600, "alg" : algorithm},
                iod_config={"rchi2_threshold" : 1000000},
                od_config={"rchi2_threshold" : 10},
                odp_config={"rchi2_threshold" : 10}
            )

            out_dir = f"{algorithm}_eps{radius}_ca{cell_area:.1f}"
            if not os.path.exists(out_dir):
                test_orbits, recovered_orbits, recovered_orbit_members = runTHOR(
                    preprocessed_observations, orbits, 
                    range_shift_config=config.RANGE_SHIFT_CONFIG,
                    cluster_link_config=config.CLUSTER_LINK_CONFIG,
                    iod_config=config.IOD_CONFIG,
                    od_config=config.OD_CONFIG,
                    odp_config=config.ODP_CONFIG,
                    out_dir=out_dir,
                    if_exists="erase",
                )
# Out:
# 20:03:06.936 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.938 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.938 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.939 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.940 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.940 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.941 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.941 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.942 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.942 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.943 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.943 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.944 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.944 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.945 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.945 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.946 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.946 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.946 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.947 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.947 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.948 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.948 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.949 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.949 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.950 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.950 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.951 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.951 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.952 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.952 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.953 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.953 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.954 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.954 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.954 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.955 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.955 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.956 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.956 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.957 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.957 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.958 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.958 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.959 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.959 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.960 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.960 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.961 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.961 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.962 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.968 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.969 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.969 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.970 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.970 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.971 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.971 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.972 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.972 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.973 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.973 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.974 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.974 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.975 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.975 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.975 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.976 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.976 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.979 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.980 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.980 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.981 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.981 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.982 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.983 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.983 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.985 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.985 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.986 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.986 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.987 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.987 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.988 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.989 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.989 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.990 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.990 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.991 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.991 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.992 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.992 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.993 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.994 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.
# 20:03:06.995 [WARNING] thor - Setting pipeline components to use min_obs: 6.
# 20:03:06.995 [WARNING] thor - Setting pipeline components to use min_arc_length: 1.0.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

thor_results = pd.read_csv("thor_results.csv", float_precision="round_trip", index_col=False)

# %%
thor_results
# Out:
#     cell_area   eps         alg  projection_time  projected_observations  \
# 0         1.0   1.0      dbscan           27.007                   11153
# 1         1.0   1.0  hotspot_2d           27.504                   11153
# 2         1.0   5.0      dbscan           27.079                   11153
# 3         1.0   5.0  hotspot_2d           26.066                   11153
# 4         1.0  10.0      dbscan           28.083                   11153
# 5         1.0  10.0  hotspot_2d           26.876                   11153
# 6         1.0  15.0      dbscan           23.696                   11153
# 7         1.0  15.0  hotspot_2d           24.834                   11153
# 8         2.5   1.0      dbscan           27.481                   27780
# 9         2.5   1.0  hotspot_2d           25.619                   27780
# 10        2.5   5.0      dbscan           28.266                   27780
# 11        2.5   5.0  hotspot_2d           27.258                   27780
# 12        2.5  10.0      dbscan           27.229                   27780
# 13        2.5  10.0  hotspot_2d           26.397                   27780
# 14        2.5  15.0      dbscan           24.840                   27780
# 15        2.5  15.0  hotspot_2d           25.693                   27780
# 16        5.0   1.0      dbscan           26.613                   55820
# 17        5.0   1.0  hotspot_2d           26.468                   55820
# 18        5.0   5.0      dbscan           26.556                   55820
# 19        5.0   5.0  hotspot_2d           27.401                   55820
# 20        5.0  10.0      dbscan           27.664                   55820
# 21        5.0  10.0  hotspot_2d           29.061                   55820
# 22        5.0  15.0      dbscan           23.492                   55820
# 23        5.0  15.0  hotspot_2d           26.226                   55820
# 24        7.5   1.0      dbscan           25.856                   82796
# 25        7.5   1.0  hotspot_2d           27.489                   82796
# 26        7.5   5.0      dbscan           28.011                   82796
# 27        7.5   5.0  hotspot_2d           26.937                   82796
# 28        7.5  10.0      dbscan           28.809                   82796
# 29        7.5  10.0  hotspot_2d           29.363                   82796
# 30        7.5  15.0      dbscan           24.850                   82796
# 31        7.5  15.0  hotspot_2d           26.378                   82796
# 32       10.0   1.0      dbscan           27.536                  105465
# 33       10.0   1.0  hotspot_2d           27.509                  105465
# 34       10.0   5.0      dbscan           27.401                  105465
# 35       10.0   5.0  hotspot_2d           27.701                  105465
# 36       10.0  10.0      dbscan           30.082                  105465
# 37       10.0  10.0  hotspot_2d           25.434                  105465
# 38       10.0  15.0      dbscan           25.647                  105465
# 39       10.0  15.0  hotspot_2d           29.932                  105465
# 40       20.0   1.0      dbscan           26.518                  183489
# 41       20.0   1.0  hotspot_2d           27.144                  183489
# 42       20.0   5.0      dbscan           28.494                  183489
# 43       20.0   5.0  hotspot_2d           27.184                  183489
# 44       20.0  10.0      dbscan           29.297                  183489
# 45       20.0  10.0  hotspot_2d           24.305                  183489
# 46       20.0  15.0      dbscan           25.454                  183489
# 47       20.0  15.0  hotspot_2d           28.659                  183489
#
#     clustering_time  restructuring_time  clusters  iod_time  iod_orbits  \
# 0            54.512               0.061         0     0.010           0
# 1            28.377               0.038         0     0.009           0
# 2            54.247               0.138        80     5.113          56
# 3            29.723               0.081        86     6.281          53
# 4            60.670               0.712      1240     7.272         820
# 5            31.822               0.626      1405    24.310         935
# 6            62.533               0.967      4345     9.090        2917
# 7            45.321               1.099      6450    11.871        4127
# 8           134.826               0.027         0     0.009           0
# 9            56.093               0.036         0     0.009           0
# 10          141.972               0.250       248     5.265         171
# 11           59.087               0.211       289     6.042         180
# 12          161.668               1.286      5231    12.584        3517
# 13           74.571               1.314      7073    60.919        4608
# 14          166.774               2.349     21309    29.143       14571
# 15          132.054               4.364     34415    48.115       21919
# 16          281.302               0.034         0     0.010           0
# 17          137.648               0.045         0     0.010           0
# 18          281.289               0.557       561     6.173         371
# 19          165.766               0.360       688     7.125         436
# 20          317.236               2.267     14224    23.671        9787
# 21          183.780               2.612     20260   139.037       13602
# 22          378.794               6.627     62103    78.671       43345
# 23          462.551              12.692     98784   132.588       63644
# 24          433.543               0.156         1     4.086           1
# 25          201.692               0.231         1     5.633           1
# 26          484.031               0.860      1073     7.169         634
# 27          277.208               0.657      1271     8.605         737
# 28          504.459               3.547     26441    42.023       17938
# 29          363.798               4.585     36544   277.127       24067
# 30          621.045              12.997    117318   147.754       80822
# 31          937.748              20.843    186740   240.299      118977
# 32          562.353               0.155         1     4.593           1
# 33          335.498               0.165         1     5.466           1
# 34          605.002               0.853      1453     7.209         872
# 35          321.566               1.007      1624     7.829         965
# 36          676.390               4.864     39115    61.501       26791
# 37          503.436               6.960     54021    77.383       36173
# 38          869.701              20.560    182950   253.873      125789
# 39         1457.359              34.880    288854   405.722      185501
# 40         1055.711               0.428         1     4.930           1
# 41          609.585               0.217         2     5.073           2
# 42         1148.449               1.201      4072    12.947        2326
# 43          731.288               1.067      4255    12.396        2468
# 44         1524.182              12.379    109309   184.072       72665
# 45         1324.892              16.857    148152   246.941       95920
# 46         2492.840              56.013    517163   844.841      345182
# 47         4240.952              90.935    817852  1346.695      509478
#
#       od_time  od_orbits  odp_time  odp_orbits
# 0       0.007        0.0     0.011         0.0
# 1       0.007        0.0     0.010         0.0
# 2       7.078        7.0    53.103         7.0
# 3       7.632        6.0    46.225         4.0
# 4      47.850       13.0    57.528        10.0
# 5     175.440        9.0    54.003         9.0
# 6     145.080       10.0    32.522        10.0
# 7     215.347        7.0    34.297         7.0
# 8       0.006        0.0     0.015         0.0
# 9       0.006        0.0     0.014         0.0
# 10     19.241       11.0    46.879        11.0
# 11     18.299       13.0    62.453        12.0
# 12    202.025       27.0    63.637        19.0
# 13    790.298       18.0    93.672        17.0
# 14    703.519       17.0    35.038        14.0
# 15   1058.304       17.0    38.603        12.0
# 16      0.007        0.0     0.022         0.0
# 17      0.006        0.0     0.021         0.0
# 18     26.559       16.0    50.253        16.0
# 19     29.182       15.0    54.095        14.0
# 20    495.429       44.0    80.606        31.0
# 21   2437.147       36.0    80.713        26.0
# 22   2012.858       37.0    60.801        30.0
# 23   3021.590       25.0    48.315        22.0
# 24      4.499        0.0     0.024         0.0
# 25      5.130        0.0     0.027         0.0
# 26     41.783       23.0    58.422        19.0
# 27     40.714       36.0    90.224        20.0
# 28    862.678       65.0   125.450        45.0
# 29   4247.871       55.0   136.517        32.0
# 30        NaN        NaN       NaN         NaN
# 31   5572.528       43.0    66.953        30.0
# 32      4.594        0.0     0.033         0.0
# 33      5.256        0.0     0.029         0.0
# 34     47.639       26.0    66.367        22.0
# 35     52.698       22.0    90.293        17.0
# 36   1266.559       79.0   130.185        55.0
# 37        NaN        NaN       NaN         NaN
# 38        NaN        NaN       NaN         NaN
# 39   8635.352       59.0   105.086        36.0
# 40      4.772        0.0     0.046         0.0
# 41      5.474        1.0    50.980         1.0
# 42    129.203       43.0   124.841        37.0
# 43    113.925       41.0   122.632        28.0
# 44   3319.209      122.0   183.078        84.0
# 45   4288.677      107.0   151.349        64.0
# 46        NaN        NaN       NaN         NaN
# 47  23453.832       76.0   163.688        50.0
